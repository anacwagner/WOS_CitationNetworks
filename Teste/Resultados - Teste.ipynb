# %% [markdown]
# # Scraping do WoS - Resultados (TESTE)

# %%
# CARREGA OS ARQUIVOS COM AS FUNÇÕES CRIADAS
from wos import *
from aux import *

# %%
# LISTA DE ANOS DOS AQUIVOS JSON
year_list = range(2010,2017)

# %%
# DICIONÁRIO COM TODOS OS PERIÓDICOS EXTRAÍDOS DOS ARQUIVOS
journals_dic = allJournals(year_list)

# %%
# EIGENFACTOR DOS PERIÓDICOS
EIG = journalsMetrics(journals_dic, 'eigen_factor', year_list)
EIG.to_csv('outputs/EIG.csv')

# FATOR DE IMPACTO DOS PERIÓDICOS
IF = journalsMetrics(journals_dic, 'impact_factor', year_list)
IF.to_csv('outputs/IF.csv')
IF.head()
# Out:
#                              TITLE   2010   2011   2012   2013   2014   2015  \
# 1       PLoS Computational Biology  5.515  5.215  4.867  4.829   4.62  4.587
# 2                   BIOINFORMATICS  4.877  5.468  5.323  4.621  4.981  5.766
# 3              BMC Systems Biology  3.565  3.148  2.982  2.853  2.435  2.208
# 4               BMC BIOINFORMATICS  3.029  2.751  3.024  2.672  2.576  2.435
# 5  JOURNAL OF MATHEMATICAL BIOLOGY  3.021  2.963  2.366  2.388  1.846  1.716
#
#     2016
# 1  4.542
# 2  7.307
# 3  2.303
# 4  2.448
# 5  1.566

# %%
# TABELA COM INFORMAÇÕES E LINKS DE TODOS OS PERIÓDICOS DA CATEGORIA SELECIONADA
ID_J = len(journals_dic.keys())  # ID dos journals
journals = pd.DataFrame(index = range(1, ID_J+1), columns = ['TITLE', 'LINK'])
journals.TITLE = journals_dic.keys()
print('Todos os Periódico da Categoria Selecionada')
print(journals.TITLE)
# Out:
# Todos os Periódico da Categoria Selecionada
# 1                            PLoS Computational Biology
# 2                                        BIOINFORMATICS
# 3                                   BMC Systems Biology
# 4                                    BMC BIOINFORMATICS
# 5                       JOURNAL OF MATHEMATICAL BIOLOGY
# 6                      Algorithms for Molecular Biology
# 7                                         BIOSTATISTICS
# 8                           Evolutionary Bioinformatics
# 9               Frontiers in Computational Neuroscience
# 10                       JOURNAL OF THEORETICAL BIOLOGY
# 11                               STATISTICS IN MEDICINE
# 12                JOURNAL OF COMPUTATIONAL NEUROSCIENCE
# 13            JOURNAL OF MOLECULAR GRAPHICS & MODELLING
# 14                     BULLETIN OF MATHEMATICAL BIOLOGY
# 15                                           BIOMETRIKA
# 16         MEDICAL & BIOLOGICAL ENGINEERING & COMPUTING
# 17              STATISTICAL METHODS IN MEDICAL RESEARCH
# 18                                           BIOMETRICS
# 19                                  IET Systems Biology
# 20    IEEE TRANSACTIONS ON INFORMATION TECHNOLOGY IN...
# 21              International Journal of Biomathematics
# 22            Theoretical Biology and Medical Modelling
# 23                     JOURNAL OF COMPUTATIONAL BIOLOGY
# 24                             MATHEMATICAL BIOSCIENCES
# 25               SAR AND QSAR IN ENVIRONMENTAL RESEARCH
# 26                                  BIOMETRICAL JOURNAL
# 27    MATHEMATICAL MEDICINE AND BIOLOGY-A JOURNAL OF...
# 28                    COMPUTERS IN BIOLOGY AND MEDICINE
# 29                               Current Bioinformatics
# 30    Computational and Mathematical Methods in Medi...
# 31    JOURNAL OF AGRICULTURAL BIOLOGICAL AND ENVIRON...
# 32          Mathematical Modelling of Natural Phenomena
# 33    International Journal of Data Mining and Bioin...
# 34                         Statistics and Its Interface
# 35                        JOURNAL OF BIOLOGICAL SYSTEMS
# 36    International Journal for Numerical Methods in...
# 37                                Molecular Informatics
# 38                          BRIEFINGS IN BIOINFORMATICS
# 39    Database-The Journal of Biological Databases a...
# 40                                           BIOSYSTEMS
# 41                                   ACTA BIOTHEORETICA
# 42               International Journal of Biostatistics
# 43             Mathematical Biosciences and Engineering
# 44                                THEORY IN BIOSCIENCES
# 45             Statistics in Biopharmaceutical Research
# 46                        Hokkaido Mathematical Journal
# 47    Wiley Interdisciplinary Reviews-Computational ...
# 48    Journal of Medical Imaging and Health Informatics
# 49                                       BioData Mining
# 50    Statistical Applications in Genetics and Molec...
# 51    Journal of Bioinformatics and Computational Bi...
# 52    Interdisciplinary Sciences-Computational Life ...
# 53    IEEE Journal of Biomedical and Health Informatics
# 54                           Research Synthesis Methods
# 55                        Frontiers in Neuroinformatics
# 56                      Journal of Biomedical Semantics
# 57                       Journal of Biological Dynamics
# 58          Computational Intelligence and Neuroscience
# 59                                 GENETIC EPIDEMIOLOGY
# Name: TITLE, dtype: object

# %%
# TABELA COM INFORMAÇÕES E LINKS DE TODOS OS ARTIGOS PUBLICADOS POR TODOS OS  PERIÓDICOS
ID_A = 1  # ID dos artigos
articles = pd.DataFrame(columns = ['TITLE', 'LINK', 'JOURNAL_ID', 'YEAR', 'LINK_CIT'])

# %%
# LOGIN NO WoS PELO LOGIN DA FGV (FORA DA REDE ALUNOS)
login()
# Out:
# User:········
# Password:········
# <selenium.webdriver.chrome.webdriver.WebDriver (session="957468eb76beacb558ca177be080c80b")>

# %%
print('INÍCIO DA FASE 1 - Buscar Todos os Artigos Publicados Por Cada Periódico')
print('1.1 - Busca Avançada de Todos os Periódicos')

# LIMPA TODOS OS RESULTADOS DE BUSCA ARMAZENADOS NO HISTÓRICO 
#clearSearchHistory()
# Out:
# INÍCIO DA FASE 1 - Buscar Todos os Artigos Publicados Por Cada Periódico
# 1.1 - Busca Avançada de Todos os Periódicos

# %%
# BUSCA TODOS OS PERIÓDICOS - ARMAZENA TODOS OS RESULTADOS NO HISTÓRICO
advancedSearch(journals, year_list)
# Out:
# Advanced Search - Journal 1
# Advanced Search - Journal 2
# Advanced Search - Journal 3
# Advanced Search - Journal 4
# Advanced Search - Journal 5
# Advanced Search - Journal 6
# Advanced Search - Journal 7
# Advanced Search - Journal 8
# Advanced Search - Journal 9
# Advanced Search - Journal 10
# Advanced Search - Journal 11
# Advanced Search - Journal 12
# Advanced Search - Journal 13
# Advanced Search - Journal 14
# Advanced Search - Journal 15
# Advanced Search - Journal 16
# Advanced Search - Journal 17
# Advanced Search - Journal 18
# Advanced Search - Journal 19
# Advanced Search - Journal 20
# Advanced Search - Journal 21
# Advanced Search - Journal 22
# Advanced Search - Journal 23
# Advanced Search - Journal 24
# Advanced Search - Journal 25
# Advanced Search - Journal 26
# Advanced Search - Journal 27
# Advanced Search - Journal 28
# Advanced Search - Journal 29
# Advanced Search - Journal 30
# Advanced Search - Journal 31
# Advanced Search - Journal 32
# Advanced Search - Journal 33
# Advanced Search - Journal 34
# Advanced Search - Journal 35
# Advanced Search - Journal 36
# Advanced Search - Journal 37
# Advanced Search - Journal 38
# Advanced Search - Journal 39
# Advanced Search - Journal 40
# Advanced Search - Journal 41
# Advanced Search - Journal 42
# Advanced Search - Journal 43
# Advanced Search - Journal 44
# Advanced Search - Journal 45
# Advanced Search - Journal 46
# Advanced Search - Journal 47
# Advanced Search - Journal 48
# Advanced Search - Journal 49
# Advanced Search - Journal 50
# Advanced Search - Journal 51
# Advanced Search - Journal 52
# Advanced Search - Journal 53
# Advanced Search - Journal 54
# Advanced Search - Journal 55
# Advanced Search - Journal 56
# Advanced Search - Journal 57
# Advanced Search - Journal 58
# Advanced Search - Journal 59
# <selenium.webdriver.chrome.webdriver.WebDriver (session="957468eb76beacb558ca177be080c80b")>

# %%
print('1.2 - Armazena os Links com os Resultados de Cada Pesquisa')
# EXTRAI TODOS OS LINKS DO HISTÓRIO DE PESQUISA
journals, driver = searchHistoryLinks(journals)
journals.to_csv('outputs/journals.csv')
journals.head()
# Out:
# 1.2 - Armazena os Links com os Resultados de Cada Pesquisa
#                              TITLE  \
# 1       PLoS Computational Biology
# 2                   BIOINFORMATICS
# 3              BMC Systems Biology
# 4               BMC BIOINFORMATICS
# 5  JOURNAL OF MATHEMATICAL BIOLOGY
#
#                                                 LINK
# 1  http://apps-webofknowledge.ez91.periodicos.cap...
# 2  http://apps-webofknowledge.ez91.periodicos.cap...
# 3  http://apps-webofknowledge.ez91.periodicos.cap...
# 4  http://apps-webofknowledge.ez91.periodicos.cap...
# 5  http://apps-webofknowledge.ez91.periodicos.cap...

# %%
print('1.3 - Listagem de Todos os Artigos de Cada Periódico')
# TODOS OS ARTIGOS ENCONTRADOS DO PERIÓDICO SELECIONADO

ID_J = len(journals)

# AQUI É SÓ UM TESTE, PARA RODA TUDO -> FAZER DE 1 A ID_J+1
for journal_id in range(47, 48):
    articles = allArticles(journals, journal_id, articles)
    # A CADA ETAPA SALVA OS RESULTADOS EM CSV
    articles.to_csv('outputs/articles.csv')
    print('Artigos do Periódico ' + str(journal_id) + ' Armazenados!')
    
articles
# Out:
# 1.3 - Listagem de Todos os Artigos de Cada Periódico
# Peiódico 47 - Total de Páginas: 3
# Artigos do Periódico 47 Armazenados!
#                                                  TITLE  \
# 1    Polarizable force field development for lipids...
# 2    About P-glycoprotein: a new drugable domain is...
# 3    Molecular 'time-machines' to unravel key biolo...
# 4    Hypercoordinate iodine(III) promoted reactions...
# 5    Prediction of two-dimensional materials by the...
# 6    Application of quantum mechanics/molecular mec...
# 7    Using PyMOL as a platform for computational dr...
# 8    Organic-inorganic interface simulation for new...
# 9    Computing optical properties of ultra-thin cry...
# 10   Electride: from computational characterization...
# 11   Making graphene nanoribbons: a theoretical exp...
# 12   Atomistic molecular dynamics simulations of AT...
# 13             Rh chemistry through the eyes of theory
# 14    Phosphorene: what can we know from computations?
# 15   Recent advances in hybrid graphene-BN planar s...
# 16   Boron nitride materials: an overview from 0D t...
# 17   GENESIS: a hybrid-parallel and multi-scale mol...
# 18   Correct electrostatic treatment of noncovalent...
# 19        Multiresolution calculation of ionic liquids
# 20   Electronic properties and charge carrier mobil...
# 21   Polarizable force fields for molecular dynamic...
# 22       Challenges in computational organic chemistry
# 23   Analytical derivatives, forces, force constant...
# 24         The Dalton quantum chemistry program system
# 25                                           Turbomole
# 26   ChemShell-a modular software package for QM/MM...
# 27     Compliance constants: are they of any real use?
# 28        Theoretical studies of nucleic acids folding
# 29              Semiempirical quantum-chemical methods
# 30   Theory and simulation of atom tunneling in che...
# ..                                                 ...
# 86   NWChem: scalable parallel computational chemistry
# 87   Software design of ACES III with the super ins...
# 88   Proline-derived organocatalysis and synergism ...
# 89                                Fluctional molecules
# 90   First-principles prediction of acidities in th...
# 91                              GROMACS-the road ahead
# 92                     Algorithms for chemoinformatics
# 93   The evolution of the RCSB Protein Data Bank we...
# 94      Polarization effects in molecular interactions
# 95                                   Cross-Conjugation
# 96                     The atomistic simulation of DNA
# 97   The quantum chemical cluster approach for mode...
# 98   Correlation diagram approach as a tool for int...
# 99   The Cambridge Structural Database: experimenta...
# 100  Green's function methods for calculating ioniz...
# 101  Cooperative dynamics of proteins unraveled by ...
# 102                             Excited-state dynamics
# 103                     Rotational barriers in alkanes
# 104  COLUMBUS-a program system for advanced multire...
# 105               Pseudopotentials and modelpotentials
# 106  Low-resolution structural approaches to study ...
# 107           The electrostatic potential: an overview
# 108  A primer on qualitative valence bond theory - ...
# 109                        Chemoinformatics: a history
# 110                        Computational chemogenomics
# 111  Maximum common subgraph isomorphism algorithms...
# 112           Noncovalent interactions in biochemistry
# 113  The empirical valence bond model: theory and a...
# 114                        Discrete molecular dynamics
# 115                Organocatalysis: Cinchona catalysts
#
#                                                   LINK JOURNAL_ID  YEAR  \
# 1    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 2    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 3    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 4    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 5    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 6    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 7    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 8    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 9    http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 10   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 11   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 12   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 13   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 14   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 15   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 16   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 17   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 18   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 19   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 20   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 21   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 22   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 23   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 24   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 25   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 26   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 27   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 28   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 29   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 30   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# ..                                                 ...        ...   ...
# 86   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 87   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 88   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 89   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 90   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 91   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 92   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 93   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 94   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 95   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 96   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 97   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 98   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 99   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 100  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 101  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 102  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 103  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 104  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 105  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 106  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 107  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 108  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 109  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 110  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 111  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 112  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 113  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 114  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 115  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
#
#     LINK_CIT
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# ..       ...
# 86       NaN
# 87       NaN
# 88       NaN
# 89       NaN
# 90       NaN
# 91       NaN
# 92       NaN
# 93       NaN
# 94       NaN
# 95       NaN
# 96       NaN
# 97       NaN
# 98       NaN
# 99       NaN
# 100      NaN
# 101      NaN
# 102      NaN
# 103      NaN
# 104      NaN
# 105      NaN
# 106      NaN
# 107      NaN
# 108      NaN
# 109      NaN
# 110      NaN
# 111      NaN
# 112      NaN
# 113      NaN
# 114      NaN
# 115      NaN
#
# [115 rows x 5 columns]

# %%
print('1.4 - Extraindo Informações de Todos os Artigos')

# PARA CADA JOURNAL, EXTRAI INFORMAÇÕES DE TODOS OS ARTIGOS
# AQUI É SÓ UM TESTE, PARA RODA TUDO -> FAZER DE 1 A ID_J+1
for journal_id in range(47, 48):
    
    articles = extractInfo(articles,journal_id)
    # A CADA ETAPA SALVA OS RESULTADOS EM CSV
    articles.to_csv('outputs/articles.csv')
    print('Informações dos Artigos do Periódico ' + str(journal_id) + ' Extraídas!')
    
articles
# Out:
# 1.4 - Extraindo Informações de Todos os Artigos
# Informações dos Artigos do Periódico 47 Extraídas!
#                                                  TITLE  \
# 1    Polarizable force field development for lipids...
# 2    About P-glycoprotein: a new drugable domain is...
# 3    Molecular 'time-machines' to unravel key biolo...
# 4    Hypercoordinate iodine(III) promoted reactions...
# 5    Prediction of two-dimensional materials by the...
# 6    Application of quantum mechanics/molecular mec...
# 7    Using PyMOL as a platform for computational dr...
# 8    Organic-inorganic interface simulation for new...
# 9    Computing optical properties of ultra-thin cry...
# 10   Electride: from computational characterization...
# 11   Making graphene nanoribbons: a theoretical exp...
# 12   Atomistic molecular dynamics simulations of AT...
# 13             Rh chemistry through the eyes of theory
# 14    Phosphorene: what can we know from computations?
# 15   Recent advances in hybrid graphene-BN planar s...
# 16   Boron nitride materials: an overview from 0D t...
# 17   GENESIS: a hybrid-parallel and multi-scale mol...
# 18   Correct electrostatic treatment of noncovalent...
# 19        Multiresolution calculation of ionic liquids
# 20   Electronic properties and charge carrier mobil...
# 21   Polarizable force fields for molecular dynamic...
# 22       Challenges in computational organic chemistry
# 23   Analytical derivatives, forces, force constant...
# 24         The Dalton quantum chemistry program system
# 25                                           Turbomole
# 26   ChemShell-a modular software package for QM/MM...
# 27     Compliance constants: are they of any real use?
# 28        Theoretical studies of nucleic acids folding
# 29              Semiempirical quantum-chemical methods
# 30   Theory and simulation of atom tunneling in che...
# ..                                                 ...
# 86   NWChem: scalable parallel computational chemistry
# 87   Software design of ACES III with the super ins...
# 88   Proline-derived organocatalysis and synergism ...
# 89                                Fluctional molecules
# 90   First-principles prediction of acidities in th...
# 91                              GROMACS-the road ahead
# 92                     Algorithms for chemoinformatics
# 93   The evolution of the RCSB Protein Data Bank we...
# 94      Polarization effects in molecular interactions
# 95                                   Cross-Conjugation
# 96                     The atomistic simulation of DNA
# 97   The quantum chemical cluster approach for mode...
# 98   Correlation diagram approach as a tool for int...
# 99   The Cambridge Structural Database: experimenta...
# 100  Green's function methods for calculating ioniz...
# 101  Cooperative dynamics of proteins unraveled by ...
# 102                             Excited-state dynamics
# 103                     Rotational barriers in alkanes
# 104  COLUMBUS-a program system for advanced multire...
# 105               Pseudopotentials and modelpotentials
# 106  Low-resolution structural approaches to study ...
# 107           The electrostatic potential: an overview
# 108  A primer on qualitative valence bond theory - ...
# 109                        Chemoinformatics: a history
# 110                        Computational chemogenomics
# 111  Maximum common subgraph isomorphism algorithms...
# 112           Noncovalent interactions in biochemistry
# 113  The empirical valence bond model: theory and a...
# 114                        Discrete molecular dynamics
# 115                Organocatalysis: Cinchona catalysts
#
#                                                   LINK JOURNAL_ID  YEAR  \
# 1    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 2    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 3    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 4    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 5    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 6    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 7    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 8    http://apps-webofknowledge.ez91.periodicos.cap...         47  2017
# 9    http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 10   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 11   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 12   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 13   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 14   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 15   http://apps-webofknowledge.ez91.periodicos.cap...         47  2016
# 16   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 17   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 18   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 19   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 20   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 21   http://apps-webofknowledge.ez91.periodicos.cap...         47  2015
# 22   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 23   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 24   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 25   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 26   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 27   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 28   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 29   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# 30   http://apps-webofknowledge.ez91.periodicos.cap...         47  2014
# ..                                                 ...        ...   ...
# 86   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 87   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 88   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 89   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 90   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 91   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 92   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 93   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 94   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 95   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 96   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 97   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 98   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 99   http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 100  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 101  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 102  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 103  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 104  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 105  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 106  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 107  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 108  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 109  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 110  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 111  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 112  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 113  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 114  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
# 115  http://apps-webofknowledge.ez91.periodicos.cap...         47  2011
#
#                                               LINK_CIT
# 1    http://apps-webofknowledge.ez91.periodicos.cap...
# 2    http://apps-webofknowledge.ez91.periodicos.cap...
# 3    http://apps-webofknowledge.ez91.periodicos.cap...
# 4    http://apps-webofknowledge.ez91.periodicos.cap...
# 5    http://apps-webofknowledge.ez91.periodicos.cap...
# 6    http://apps-webofknowledge.ez91.periodicos.cap...
# 7    http://apps-webofknowledge.ez91.periodicos.cap...
# 8    http://apps-webofknowledge.ez91.periodicos.cap...
# 9    http://apps-webofknowledge.ez91.periodicos.cap...
# 10   http://apps-webofknowledge.ez91.periodicos.cap...
# 11   http://apps-webofknowledge.ez91.periodicos.cap...
# 12   http://apps-webofknowledge.ez91.periodicos.cap...
# 13   http://apps-webofknowledge.ez91.periodicos.cap...
# 14   http://apps-webofknowledge.ez91.periodicos.cap...
# 15   http://apps-webofknowledge.ez91.periodicos.cap...
# 16   http://apps-webofknowledge.ez91.periodicos.cap...
# 17   http://apps-webofknowledge.ez91.periodicos.cap...
# 18   http://apps-webofknowledge.ez91.periodicos.cap...
# 19   http://apps-webofknowledge.ez91.periodicos.cap...
# 20   http://apps-webofknowledge.ez91.periodicos.cap...
# 21   http://apps-webofknowledge.ez91.periodicos.cap...
# 22   http://apps-webofknowledge.ez91.periodicos.cap...
# 23   http://apps-webofknowledge.ez91.periodicos.cap...
# 24   http://apps-webofknowledge.ez91.periodicos.cap...
# 25   http://apps-webofknowledge.ez91.periodicos.cap...
# 26   http://apps-webofknowledge.ez91.periodicos.cap...
# 27   http://apps-webofknowledge.ez91.periodicos.cap...
# 28   http://apps-webofknowledge.ez91.periodicos.cap...
# 29   http://apps-webofknowledge.ez91.periodicos.cap...
# 30   http://apps-webofknowledge.ez91.periodicos.cap...
# ..                                                 ...
# 86   http://apps-webofknowledge.ez91.periodicos.cap...
# 87   http://apps-webofknowledge.ez91.periodicos.cap...
# 88   http://apps-webofknowledge.ez91.periodicos.cap...
# 89   http://apps-webofknowledge.ez91.periodicos.cap...
# 90   http://apps-webofknowledge.ez91.periodicos.cap...
# 91   http://apps-webofknowledge.ez91.periodicos.cap...
# 92   http://apps-webofknowledge.ez91.periodicos.cap...
# 93   http://apps-webofknowledge.ez91.periodicos.cap...
# 94   http://apps-webofknowledge.ez91.periodicos.cap...
# 95   http://apps-webofknowledge.ez91.periodicos.cap...
# 96   http://apps-webofknowledge.ez91.periodicos.cap...
# 97   http://apps-webofknowledge.ez91.periodicos.cap...
# 98   http://apps-webofknowledge.ez91.periodicos.cap...
# 99   http://apps-webofknowledge.ez91.periodicos.cap...
# 100  http://apps-webofknowledge.ez91.periodicos.cap...
# 101  http://apps-webofknowledge.ez91.periodicos.cap...
# 102  http://apps-webofknowledge.ez91.periodicos.cap...
# 103  http://apps-webofknowledge.ez91.periodicos.cap...
# 104  http://apps-webofknowledge.ez91.periodicos.cap...
# 105  http://apps-webofknowledge.ez91.periodicos.cap...
# 106  http://apps-webofknowledge.ez91.periodicos.cap...
# 107  http://apps-webofknowledge.ez91.periodicos.cap...
# 108  http://apps-webofknowledge.ez91.periodicos.cap...
# 109  http://apps-webofknowledge.ez91.periodicos.cap...
# 110  http://apps-webofknowledge.ez91.periodicos.cap...
# 111  http://apps-webofknowledge.ez91.periodicos.cap...
# 112  http://apps-webofknowledge.ez91.periodicos.cap...
# 113  http://apps-webofknowledge.ez91.periodicos.cap...
# 114  http://apps-webofknowledge.ez91.periodicos.cap...
# 115  http://apps-webofknowledge.ez91.periodicos.cap...
#
# [115 rows x 5 columns]

# %%
print('INÍCIO DA FASE 2 - ARMAZENAR TODAS AS CITAÇÕES FEITAS POR CADA ARTIGO')

# TABELA COM INFORMAÇÕES GERAIS DOS PERIÓDICOS UTILIZADOS PARA A CONSTRUÇÃO DA REDE DE CITAÇÕES
journals_cit = pd.DataFrame(columns = ['TITLE', 'TOT_DEGREE', 'TOT_ART'])
journals_cit.TITLE = journals.TITLE 
journals_cit.TOT_DEGREE = 0
journals_cit.TOT_ART = 0

journals_cit.head()


# TABELA COM INFORMAÇÕES GERAIS DOS ARTIGOS UTILIZADOS PARA A CONSTRUÇÃO DA REDE DE CITAÇÕES
articles_cit = pd.DataFrame(columns = ['TITLE', 'JOURNAL_ID', 'YEAR', 'CITED_IN', 'CITED_OUT'])
articles_cit.TITLE = articles.TITLE
articles_cit.JOURNAL_ID = articles.JOURNAL_ID
articles_cit.YEAR = articles.YEAR
articles_cit.CITED_IN = 0
articles_cit.CITED_OUT = 0

ID_A_CIT = len(articles_cit)
articles_cit.head()


# TABELA COM INFORMAÇÕES GERAIS DAS CITAÇÕES
citations = pd.DataFrame(columns = ['SOURCE_A', 'SOURCE_J', 'TARGET_A', 'TARGET_J', 'YEAR'])
# Out:
# INÍCIO DA FASE 2 - ARMAZENAR TODAS AS CITAÇÕES FEITAS POR CADA ARTIGO

# %%
print('2.1 - Listando Todas as Citações Realizadas por Cada Artigo')
articles_cit, journals_cit, citations = allCitations(articles, articles_cit, journals_cit, citations)
# SALVA OS RESULTADOS EM CSV
articles_cit.to_csv('outputs/articles_cit.csv')
journals_cit.to_csv('outputs/journals_cit.csv')
citations.to_csv('outputs/citations.csv')
# Out:
# 2.1 - Listando Todas as Citações Realizadas por Cada Artigo
# Citações Feitas pelo Artigo ID = 1
# Artigo do Journal ID = 47
# /Users/acwgdb/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/acwgdb/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/acwgdb/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/acwgdb/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Citações Feitas pelo Artigo ID = 2
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 3
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 4
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 5
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 6
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 7
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 8
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 9
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 10
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 11
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 12
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 13
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 14
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 15
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 16
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 17
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 18
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 19
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 20
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 21
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 22
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 23
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 24
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 25
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 26
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 27
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 28
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 29
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 30
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 31
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 32
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 33
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 34
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 35
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 36
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 37
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 38
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 39
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 40
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 41
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 42
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 43
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 44
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 45
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 46
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 47
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 48
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 49
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 50
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 51
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 52
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 53
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 54
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 55
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 56
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 57
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 58
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 59
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 60
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 61
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 62
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 63
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 64
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 65
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 66
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 67
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 68
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 69
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 70
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 71
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 72
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 73
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 74
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 75
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 76
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 77
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 78
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 79
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 80
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 81
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 82
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 83
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 84
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 85
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 86
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 87
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 88
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 89
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 90
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 91
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 92
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 93
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 94
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 95
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 96
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 97
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 98
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 99
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 100
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 101
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 102
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 103
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 104
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 105
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 106
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 107
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 108
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 109
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 110
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 111
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 112
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 113
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 114
# Artigo do Journal ID = 47
# Citações Feitas pelo Artigo ID = 115
# Artigo do Journal ID = 47

# %%
citations
# Out:
#      SOURCE_A SOURCE_J TARGET_A TARGET_J  YEAR
# 1           1       47      116       60  2006
# 2           1       47      117       61  2006
# 3           1       47      118       61  2003
# 4           1       47      119       62  2004
# 5           1       47       21       63  2015
# 6           1       47      120       64  1999
# 7           1       47      121       65  2006
# 8           1       47      122       66  2011
# 9           1       47      123       67  2012
# 10          1       47      124       68  2009
# 11          1       47      125       64  2004
# 12          1       47      126       69  2009
# 13          1       47      127       61  1998
# 14          1       47      128       64  1999
# 15          1       47      129       70  2008
# 16          1       47      130       71  2013
# 17          1       47      131       71  2013
# 18          1       47      132       69  2001
# 19          1       47      133       72  2009
# 20          1       47      134       61  1999
# 21          1       47      135       61  2009
# 22          1       47      136       71  2009
# 23          1       47      137       73  2008
# 24          1       47      138       74  2014
# 25          1       47      139       75  2012
# 26          1       47      140       76  2012
# 27          1       47      141       62  2007
# 28          1       47      142       77  1981
# 29          1       47      143       78  2008
# 30          1       47      144       69  2009
# ...       ...      ...      ...      ...   ...
# 6852      115       47     6332      325  2007
# 6853      115       47     6333       80  2006
# 6854      115       47     6334       80  1981
# 6855      115       47     4968       87  2008
# 6856      115       47     6335      187  2006
# 6857      115       47     6336      167  1999
# 6858      115       47     6337      187  2005
# 6859      115       47     6338      185  2008
# 6860      115       47     6339       91  1994
# 6861      115       47     6340       91  2007
# 6862      115       47     6341      187  2006
# 6863      115       47     6342      656  2010
# 6864      115       47     6343      207  2007
# 6865      115       47     6344      657  2007
# 6866      115       47     6345      193  2000
# 6867      115       47     6346       80  2006
# 6868      115       47     6347       80  2005
# 6869      115       47     6348      189  2008
# 6870      115       47     6349      205  2007
# 6871      115       47     6350      655  2000
# 6872      115       47     6351      615  2001
# 6873      115       47     6352      615  1997
# 6874      115       47     6353      185  2008
# 6875      115       47     4184       80  1999
# 6876      115       47     6354       94  2008
# 6877      115       47     6355      205  2005
# 6878      115       47     6356       94  2006
# 6879      115       47     6357       69  2009
# 6880      115       47     6358      270  2004
# 6881      115       47     6359       88  2003
#
# [6881 rows x 5 columns]

# %%
articles_cit
# Out:
#                                                   TITLE JOURNAL_ID  YEAR  \
# 1     Polarizable force field development for lipids...         47  2017
# 2     About P-glycoprotein: a new drugable domain is...         47  2017
# 3     Molecular 'time-machines' to unravel key biolo...         47  2017
# 4     Hypercoordinate iodine(III) promoted reactions...         47  2017
# 5     Prediction of two-dimensional materials by the...         47  2017
# 6     Application of quantum mechanics/molecular mec...         47  2017
# 7     Using PyMOL as a platform for computational dr...         47  2017
# 8     Organic-inorganic interface simulation for new...         47  2017
# 9     Computing optical properties of ultra-thin cry...         47  2016
# 10    Electride: from computational characterization...         47  2016
# 11    Making graphene nanoribbons: a theoretical exp...         47  2016
# 12    Atomistic molecular dynamics simulations of AT...         47  2016
# 13              Rh chemistry through the eyes of theory         47  2016
# 14     Phosphorene: what can we know from computations?         47  2016
# 15    Recent advances in hybrid graphene-BN planar s...         47  2016
# 16    Boron nitride materials: an overview from 0D t...         47  2015
# 17    GENESIS: a hybrid-parallel and multi-scale mol...         47  2015
# 18    Correct electrostatic treatment of noncovalent...         47  2015
# 19         Multiresolution calculation of ionic liquids         47  2015
# 20    Electronic properties and charge carrier mobil...         47  2015
# 21    Polarizable force fields for molecular dynamic...         47  2015
# 22        Challenges in computational organic chemistry         47  2014
# 23    Analytical derivatives, forces, force constant...         47  2014
# 24          The Dalton quantum chemistry program system         47  2014
# 25                                            Turbomole         47  2014
# 26    ChemShell-a modular software package for QM/MM...         47  2014
# 27      Compliance constants: are they of any real use?         47  2014
# 28         Theoretical studies of nucleic acids folding         47  2014
# 29               Semiempirical quantum-chemical methods         47  2014
# 30    Theory and simulation of atom tunneling in che...         47  2014
# ...                                                 ...        ...   ...
# 6330  A QM/MM study of the asymmetric dihydroxylatio...         47  2005
# 6331  Asymmetric aza-henry reaction under phase tran...         47  2008
# 6332  Density functional theory study of the Cinchon...         47  2007
# 6333  Theoretical studies on the bifunctionality of ...         47  2006
# 6334  ADDITION OF AROMATIC THIOLS TO CONJUGATED CYCL...         47  1981
# 6335  Enantioselective catalytic intramolecular cycl...         47  2006
# 6336  Stereoelectronic features of the cinchona alka...         47  1999
# 6337  The quest for quinine: Those who won the battl...         47  2005
# 6338  Asymmetric organocatalysed [1,3]-sigmatropic r...         47  2008
# 6339               CATALYTIC ASYMMETRIC DIHYDROXYLATION         47  1994
# 6340      Asymmetric catalysis at chiral metal surfaces         47  2007
# 6341          Asymmetric organocatalytic Henry reaction         47  2006
# 6342   Cinchona Alkaloids in Asymmetric Organocatalysis         47  2010
# 6343  Dimer formation of cinchonidine in liquid phas...         47  2007
# 6344  NMR spectroscopic and theoretical evidence of ...         47  2007
# 6345  Molecular dynamics-based models explain the un...         47  2000
# 6346  Effect of protonation on the conformation of c...         47  2006
# 6347  Catalytic enantioselective aza-Henry reaction ...         47  2005
# 6348  Bifunctional organocatalyst for methanolytic d...         47  2008
# 6349  Computing reliable energetics for conjugate ad...         47  2007
# 6350  Enantiodiscrimination by a quinine-based chira...         47  2000
# 6351  Conformational analysis of epiquinine and epiq...         47  2001
# 6352  Conformational analysis of the antimalarial ag...         47  1997
# 6353  Edge-to-face CH/pi aromatic interaction and mo...         47  2008
# 6354  Conformational behavior of cinchonidine revisi...         47  2008
# 6355  Highly enantioselective conjugate addition of ...         47  2005
# 6356  Solvent-induced conformational changes of O-ph...         47  2006
# 6357  The Performance of Computational Techniques in...         47  2009
# 6358  Absolute configuration modulation attenuated t...         47  2004
# 6359                        Privileged chiral catalysts         47  2003
#
#       CITED_IN  CITED_OUT
# 1            0        161
# 2            0        151
# 3            0        127
# 4            0         96
# 5            0        132
# 6            0        214
# 7            0         46
# 8            0         99
# 9            0        126
# 10           0         60
# 11           0         49
# 12           0         75
# 13           0         48
# 14           1         82
# 15           0         67
# 16           0         52
# 17           0         95
# 18           0         34
# 19           0         86
# 20           0         47
# 21           2         97
# 22           0         30
# 23           0         53
# 24           0        147
# 25           0         31
# 26           0         53
# 27           0         12
# 28           0         68
# 29           1        105
# 30           0         69
# ...        ...        ...
# 6330         1          0
# 6331         1          0
# 6332         1          0
# 6333         1          0
# 6334         1          0
# 6335         1          0
# 6336         1          0
# 6337         1          0
# 6338         1          0
# 6339         1          0
# 6340         1          0
# 6341         1          0
# 6342         1          0
# 6343         1          0
# 6344         1          0
# 6345         1          0
# 6346         1          0
# 6347         1          0
# 6348         1          0
# 6349         1          0
# 6350         1          0
# 6351         1          0
# 6352         1          0
# 6353         1          0
# 6354         1          0
# 6355         1          0
# 6356         1          0
# 6357         1          0
# 6358         1          0
# 6359         1          0
#
# [6359 rows x 5 columns]

# %%
journals_cit
# Out:
#                                                  TITLE  TOT_DEGREE  TOT_ART
# 1                           PLoS Computational Biology           0        0
# 2                                       BIOINFORMATICS          28        0
# 3                                  BMC Systems Biology           0        0
# 4                                   BMC BIOINFORMATICS          10        0
# 5                      JOURNAL OF MATHEMATICAL BIOLOGY           0        0
# 6                     Algorithms for Molecular Biology           0        0
# 7                                        BIOSTATISTICS           0        0
# 8                          Evolutionary Bioinformatics           0        0
# 9              Frontiers in Computational Neuroscience           0        0
# 10                      JOURNAL OF THEORETICAL BIOLOGY           1        0
# 11                              STATISTICS IN MEDICINE           0        0
# 12               JOURNAL OF COMPUTATIONAL NEUROSCIENCE           0        0
# 13           JOURNAL OF MOLECULAR GRAPHICS & MODELLING          19        0
# 14                    BULLETIN OF MATHEMATICAL BIOLOGY           0        0
# 15                                          BIOMETRIKA           0        0
# 16        MEDICAL & BIOLOGICAL ENGINEERING & COMPUTING           0        0
# 17             STATISTICAL METHODS IN MEDICAL RESEARCH           0        0
# 18                                          BIOMETRICS           0        0
# 19                                 IET Systems Biology           0        0
# 20   IEEE TRANSACTIONS ON INFORMATION TECHNOLOGY IN...           0        0
# 21             International Journal of Biomathematics           0        0
# 22           Theoretical Biology and Medical Modelling           0        0
# 23                    JOURNAL OF COMPUTATIONAL BIOLOGY           1        0
# 24                            MATHEMATICAL BIOSCIENCES           0        0
# 25              SAR AND QSAR IN ENVIRONMENTAL RESEARCH           1        0
# 26                                 BIOMETRICAL JOURNAL           0        0
# 27   MATHEMATICAL MEDICINE AND BIOLOGY-A JOURNAL OF...           0        0
# 28                   COMPUTERS IN BIOLOGY AND MEDICINE           0        0
# 29                              Current Bioinformatics           0        0
# 30   Computational and Mathematical Methods in Medi...           0        0
# ..                                                 ...         ...      ...
# 628  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...           1        0
# 629  ANNUAL REVIEW OF INFORMATION SCIENCE AND TECHN...           1        0
# 630                                  ASLIB PROCEEDINGS           1        0
# 631                     JOURNAL OF INFORMATION SCIENCE           1        0
# 632                            ARTIFICIAL INTELLIGENCE           1        0
# 633                            NATURE REVIEWS GENETICS           3        0
# 634  JOURNAL OF THE AMERICAN SOCIETY FOR INFORMATIO...           1        0
# 635                                          COMPUTING           1        0
# 636                          SIAM JOURNAL ON COMPUTING           1        0
# 637                        OPERATIONS RESEARCH LETTERS           2        0
# 638  GRAPH BASED REPRESENTATIONS IN PATTERN RECOGNI...           1        0
# 639           COMPUTER APPLICATIONS IN THE BIOSCIENCES           1        0
# 640  IEEE TRANSACTIONS ON PATTERN ANALYSIS AND MACH...           2        0
# 641                                       ALGORITHMICA           1        0
# 642  ZEITSCHRIFT FUR NATURFORSCHUNG SECTION A-A JOU...           1        0
# 643                                MOLECULAR DIVERSITY           1        0
# 644       IN SILICO SIMULATION OF BIOLOGICAL PROCESSES           1        0
# 645                       THEORETICAL COMPUTER SCIENCE           1        0
# 646                     SOFTWARE-PRACTICE & EXPERIENCE           1        0
# 647                                   COMPUTER JOURNAL           1        0
# 648                                OPERATIONS RESEARCH           1        0
# 649                         IMAGE AND VISION COMPUTING           1        0
# 650     ANNUAL REVIEW OF BIOPHYSICS AND BIOENGINEERING           2        0
# 651                                       PLOS BIOLOGY           1        0
# 652                   CURRENT OPINION IN BIOTECHNOLOGY           1        0
# 653                                                RNA           1        0
# 654               MACROMOLECULAR CRYSTALLOGRAPHY, PT D           1        0
# 655                                          CHIRALITY           2        0
# 656                                SYNTHESIS-STUTTGART           1        0
# 657                               JOURNAL OF CATALYSIS           1        0
#
# [657 rows x 3 columns]
